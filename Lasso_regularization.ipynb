# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt 
import numpy as np

# %%
x,y= make_regression(n_samples=200, n_features=1, n_informative=1, n_targets=1, noise=18, random_state=13 )

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [21.70423041]
# -1.818479848657581

# %%
from sklearn.linear_model import Lasso
Ls= Lasso(8)
Ls.fit(x,y)
print(Ls.coef_)
print(Ls.intercept_)
# Out:
# [11.33952249]
# -2.2699054635340445

# %%
plt.plot(x,y,'b.')
plt.plot(x, lr.predict(x), color='red',label='alpha=0')
plt.plot(x, Ls.predict(x), color='orange',label='alpha=10')
plt.legend()
